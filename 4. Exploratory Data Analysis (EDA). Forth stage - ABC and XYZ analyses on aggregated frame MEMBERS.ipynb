# %% [markdown]
# # "ABC" анализ данных по укрупненному датасету members_13

# %%
import numpy as np
import pandas as pd

# %% [raw]
# таблица members - фиктивный список из членов различных Funs Clubs
# (одни клубы могут находится в разных городах и штатах США):
# member_name - имя, фамилия
# birthday - дата рождения (ограничено по возрасту 18-85 лет)
# sex - Male, Female, Nonbinary
# Profession - профессия, основное занятие
# salary_usd$ - ежемесячный доход по основному месту работы
# entry_date - дата вхождения в члены клуба Funs Club (срок существования клуба от 3 до 5 лет)
# group_id - group_id клуба (Funs club), членом которого он является
# city_name - город проживания
# state_name - штат проживания
# age - возраст на текущий момент
# fun_club_name - название клуба (Funs club), членом которого он является
# category_id - id категории сферы интересов, к которому относится деятельность клуба
# monthly_fee_USD$ - сумма ежемесячных членских взносов
# category_name - название категории сферы интересов, к которому относится деятельность клуба
# membership_duration_days - общая длительность пребывания в статусе члена клуба
# sum_fee_paid, USD$ - общая сумма выплаченных каждым членов взносов за всё время пребывания

# %%
members_13 = pd.read_csv('members_13.csv', parse_dates = ['birthday', 'entry_date'])
members_13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130989 entries, 0 to 130988
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   member_name               130989 non-null  object
#  1   birthday                  130989 non-null  datetime64[ns]
#  2   sex                       130989 non-null  object
#  3   profession                130989 non-null  object
#  4   salary_usd$               130989 non-null  int64
#  5   entry_date                130989 non-null  datetime64[ns]
#  6   group_id                  130989 non-null  int64
#  7   city_name                 130989 non-null  object
#  8   state_name                130989 non-null  object
#  9   age                       130989 non-null  int64
#  10  fun_club_name             130974 non-null  object
#  11  category_id               130989 non-null  int64
#  12  monthly_fee_USD$          130989 non-null  int64
#  13  category_name             130989 non-null  object
#  14  membership_duration_days  130989 non-null  int64
#  15  sum_fee_paid, USD$        130989 non-null  float64
# dtypes: datetime64[ns](2), float64(1), int64(6), object(7)
# memory usage: 16.0+ MB

# %%
# все имена членов клубов уникальные
members_13.member_name.nunique()
# Out:
# 130989

# %%
# все значения в таблице Not NaN
members_13.where(members_13.notna())
# Out:
#                member_name   birthday sex  \
# 0            Vanessa Casey 1960-08-08   F
# 1             Cheryl Carey 1958-12-11   N
# 2            Kendra Valdez 1962-06-16   M
# 3              Toni Baxter 1992-03-21   F
# 4             Shaun Zuniga 1999-07-04   N
# ...                    ...        ...  ..
# 130984     George Mcdaniel 1943-03-14   M
# 130985      Kevin Diaz DVM 1999-05-16   F
# 130986  Latasha Alvarez MD 1953-07-07   N
# 130987     Hector Davidson 1945-05-05   N
# 130988     Marissa Krueger 1960-06-15   F
#
#                                    profession  salary_usd$ entry_date  \
# 0             Engineer, manufacturing systems         1884 2018-05-24
# 1                Trade union research officer         1518 2019-11-14
# 2                          Press photographer         1669 2018-08-06
# 3       Emergency planning/management officer         3818 2017-07-18
# 4             Runner, broadcasting/film/video         4962 2017-11-18
# ...                                       ...          ...        ...
# 130984                            Comptroller         2393 2018-04-14
# 130985               Customer service manager         4874 2018-12-27
# 130986                            Interpreter         2579 2018-09-20
# 130987                          Lexicographer         2890 2018-11-18
# 130988                        Sales executive         3484 2019-09-08
#
#         group_id         city_name     state_name  age  \
# 0       19927387        Montgomery  West Virginia   63
# 1       19712846           Colonia     New Jersey   65
# 2       10528562          Pinckney       Michigan   61
# 3        1291778          Florence       Kentucky   31
# 4       26053931         Nickerson         Kansas   24
# ...          ...               ...            ...  ...
# 130984   1222759          Oakhurst     California   80
# 130985   2137821  Spring Lake Park      Minnesota   24
# 130986  23343110     Newton County       Missouri   70
# 130987  10982362           Houston         Alaska   78
# 130988   1454174     Gosper County       Nebraska   63
#
#                                             fun_club_name  category_id  \
# 0                            Events That Make You Smarter            6
# 1                               Mix Professionals Chicago            9
# 2                            Madison Square Park Mommies!           25
# 3                    San Francisco Dodgeball Meetup Group           32
# 4                                Passionate Concert Goers           21
# ...                                                   ...          ...
# 130984                           RHYTHMflow  Explorations           21
# 130985                        Aquatic Voyagers Scuba Club           23
# 130986                      Chicago Womens Soccer Meet up           32
# 130987  Chicago Indonesian (Bahasa Indonesia) Language...           16
# 130988                                        Beer. Good.           10
#
#         monthly_fee_USD$               category_name  \
# 0                      7        Education & Learning
# 1                     18                     Fitness
# 2                     19            Parents & Family
# 3                      1         Sports & Recreation
# 4                      9                       Music
# ...                  ...                         ...
# 130984                21                       Music
# 130985                18        Outdoors & Adventure
# 130986                 5         Sports & Recreation
# 130987                23  Language & Ethnic Identity
# 130988                 9                Food & Drink
#
#         membership_duration_days  sum_fee_paid, USD$
# 0                           1803               421.0
# 1                           1264               758.0
# 2                           1729              1095.0
# 3                           2113                70.0
# 4                           1990               597.0
# ...                          ...                 ...
# 130984                      1843              1290.0
# 130985                      1586               952.0
# 130986                      1684               281.0
# 130987                      1625              1246.0
# 130988                      1331               399.0
#
# [130989 rows x 16 columns]

# %%
# переименуем "проблемные колонки"
members_13 = members_13.rename(columns={'salary_usd$':'salary', 'monthly_fee_USD$':'monthly_fee', 'sum_fee_paid, USD$':'sum_fee_paid'})

# %% [raw]
# Что такое ABC-анализ
# Смысл ABC-анализа — выделение из большого количества наиболее ценных клиентов, на которых нужно
# сосредоточить внимание. По результатам анализа можно разбить клиентов на сегменты и разработать
# стратегию продаж по каждому из них. В основе анализа лежит принцип Парето: 20% клиентов
# обеспечивают 80% прибыли.
# A — наиболее ценные клиенты. Это именно те 20%, которые приносят 80% прибыли.
# B — промежуточные клиенты. 30% клиентов, на долю которых приходится 15% доходности.
# C — наименее ценные. Оставшиеся 50% приносят 5% от всех доходов.

# %% [raw]
# ABC анализ на основании данных по отдельным клубам
# (используя group_id) и суммам выплаченных взносов sum_fee_paid, USD$.
#
# Логика анализа: есть клубы, которые собирают больше членских взносов => уровень платежеспособности и заинтересованности
# членов этих клубов более высокий => разумнее сосредоточить таргетированную рекламу соответствующих
# категорий товаров именно в этом сегменте клубов

# %%
# сгруппируем данные по id клубов, агрегируем по сумме выплаченных взносов,
# ранжируем по убыванию этой суммы
df_abc=members_13.groupby('group_id', as_index=False).agg({'sum_fee_paid':'sum'})\
       .sort_values('sum_fee_paid', ascending=False) 
df_abc
# Out:
#       group_id  sum_fee_paid
# 6446  23754254       38095.0
# 4091  19012818       36795.0
# 2567  10825092       36293.0
# 710    1288361       36127.0
# 3425  18383769       34866.0
# ...        ...           ...
# 2328   8156102           0.0
# 3500  18468547           0.0
# 2326   8150612           0.0
# 6270  23348398           0.0
# 5621  21789865           0.0
#
# [8035 rows x 2 columns]

# %%
# имеем 329 клубов, в которых видимо членские взносы вообще не взымались.
# это "халявные" клубы и для целей исследования они мало интересны
df_abc['sum_fee_paid'].where(df_abc['sum_fee_paid']==0).value_counts()
# Out:
# 0.0    329
# Name: sum_fee_paid, dtype: int64

# %%
# уберем из дальнейшего исследования эти "халявные" клубы
df_abc=members_13.query('sum_fee_paid !=0')\
        .groupby('group_id', as_index=False).agg({'sum_fee_paid':'sum'})\
        .sort_values('sum_fee_paid', ascending=False) 
df_abc
# Out:
#       group_id  sum_fee_paid
# 6172  23754254       38095.0
# 3914  19012818       36795.0
# 2450  10825092       36293.0
# 681    1288361       36127.0
# 3272  18383769       34866.0
# ...        ...           ...
# 6407  24446955         467.0
# 2261   8552732         445.0
# 7482  26157417         430.0
# 6288  24163847         418.0
# 5044  20676096         341.0
#
# [7706 rows x 2 columns]

# %%
# создаем переменную общей суммы взносов
total_sum_fees = df_abc.sum_fee_paid.sum()
total_sum_fees
# Out:
# 86236301.0

# %%
# доля (процент) суммы взносов для каждого клуба в общей сумме взносов
df_abc['share_of_total_fees']=df_abc.sum_fee_paid/total_sum_fees*100
df_abc
# Out:
#       group_id  sum_fee_paid  share_of_total_fees
# 6172  23754254       38095.0             0.044175
# 3914  19012818       36795.0             0.042668
# 2450  10825092       36293.0             0.042086
# 681    1288361       36127.0             0.041893
# 3272  18383769       34866.0             0.040431
# ...        ...           ...                  ...
# 6407  24446955         467.0             0.000542
# 2261   8552732         445.0             0.000516
# 7482  26157417         430.0             0.000499
# 6288  24163847         418.0             0.000485
# 5044  20676096         341.0             0.000395
#
# [7706 rows x 3 columns]

# %%
# добавляем колонку с кумулятивной суммой процентов
df_abc['cum_sum']=df_abc.share_of_total_fees.cumsum()
df_abc
# Out:
#       group_id  sum_fee_paid  share_of_total_fees     cum_sum
# 6172  23754254       38095.0             0.044175    0.044175
# 3914  19012818       36795.0             0.042668    0.086843
# 2450  10825092       36293.0             0.042086    0.128928
# 681    1288361       36127.0             0.041893    0.170821
# 3272  18383769       34866.0             0.040431    0.211252
# ...        ...           ...                  ...         ...
# 6407  24446955         467.0             0.000542   99.998105
# 2261   8552732         445.0             0.000516   99.998621
# 7482  26157417         430.0             0.000499   99.999120
# 6288  24163847         418.0             0.000485   99.999605
# 5044  20676096         341.0             0.000395  100.000000
#
# [7706 rows x 4 columns]

# %%
# присвоим значения  по границам "A<80,B<95,C>95"
df_abc['abc'] = np.where(df_abc['cum_sum']<80, 'A', np.where((df_abc['cum_sum']<95), 'B', 'C'))
df_abc
# Out:
#       group_id  sum_fee_paid  share_of_total_fees     cum_sum abc
# 6172  23754254       38095.0             0.044175    0.044175   A
# 3914  19012818       36795.0             0.042668    0.086843   A
# 2450  10825092       36293.0             0.042086    0.128928   A
# 681    1288361       36127.0             0.041893    0.170821   A
# 3272  18383769       34866.0             0.040431    0.211252   A
# ...        ...           ...                  ...         ...  ..
# 6407  24446955         467.0             0.000542   99.998105   C
# 2261   8552732         445.0             0.000516   99.998621   C
# 7482  26157417         430.0             0.000499   99.999120   C
# 6288  24163847         418.0             0.000485   99.999605   C
# 5044  20676096         341.0             0.000395  100.000000   C
#
# [7706 rows x 5 columns]

# %%
df_abc.query('abc == "A"')
# Out:
#       group_id  sum_fee_paid  share_of_total_fees    cum_sum abc
# 6172  23754254       38095.0             0.044175   0.044175   A
# 3914  19012818       36795.0             0.042668   0.086843   A
# 2450  10825092       36293.0             0.042086   0.128928   A
# 681    1288361       36127.0             0.041893   0.170821   A
# 3272  18383769       34866.0             0.040431   0.211252   A
# ...        ...           ...                  ...        ...  ..
# 4946  20415318        9618.0             0.011153  79.945056   A
# 2812  14783972        9615.0             0.011150  79.956205   A
# 7627  26288108        9606.0             0.011139  79.967345   A
# 7467  26142870        9603.0             0.011136  79.978480   A
# 6199  23830511        9597.0             0.011129  79.989609   A
#
# [4213 rows x 5 columns]

# %%
# процент клубов класса "А"
4213/7706*100
# Out:
# 54.671684401764864

# %%
# процент клубов класса "А" от общей суммы взносов
(df_abc.query('abc == "A"').sum_fee_paid.sum())/total_sum_fees*100
# Out:
# 79.98960901627726

# %%
df_abc.query('abc == "A"').sum_fee_paid.sum()
# Out:
# 68980080.0

# %% [markdown]
# В нашем случае почти 55% клубов обеспечивают 80% общей суммы взносов.
# Принимаем этот факт как данность.
# Выведем фрейм со списком наименований клубов класса "А"

# %%
df_abc_A = df_abc.query('abc == "A"')['group_id'].to_frame()
df_abc_A
# Out:
#       group_id
# 6172  23754254
# 3914  19012818
# 2450  10825092
# 681    1288361
# 3272  18383769
# ...        ...
# 4946  20415318
# 2812  14783972
# 7627  26288108
# 7467  26142870
# 6199  23830511
#
# [4213 rows x 1 columns]

# %%
# извлечем соответствующие название клубов класса А из таблицы member_13 и проверим по кол-ву уникальных значений
fun_club_class_A=df_abc_A.merge(members_13[['group_id', 'fun_club_name']], how='left', on='group_id')
len(list(fun_club_class_A.fun_club_name.unique()))
# Out:
# 4213

# %%
# распечатем список клубов класса А. В дальнейшем его можно изпользовать для таргетированной рекламы.
array = fun_club_class_A.fun_club_name.unique()
class_A_clubs = pd.DataFrame(array, columns = ['club_name'])
class_A_clubs
# Out:
#                                  club_name
# 0                Cultural Explorations NYC
# 1                             Films@Facets
# 2                      New York Kayak Polo
# 3      The New York City MBTI Meetup Group
# 4           Intro to Voice Training -- NYC
# ...                                    ...
# 4208         UES New York Book Club Meetup
# 4209          Composing Film/Game Music SF
# 4210  Manchester United NYC watch parties!
# 4211    New York Adult Kick Scooter Meetup
# 4212    Bay Area Classical Mandolin Lovers
#
# [4213 rows x 1 columns]

# %% [markdown]
# # "XYZ" анализ

# %% [raw]
# Что такое XYZ-анализ
# XYZ-анализ применяется для определения характера спроса. С помощью него можно понять
# насколько стабильными являются продажи.
# X — стабильные покупки, высокая степень прогнозирования.
# Y — нерегулярные покупки, средние возможности для прогнозирования, могут зависеть от
# сезонности.
# Z — редкие покупки, единичные заказы, невозможно спрогнозировать.

# %% [raw]
# XYZ анализ на основании данных по отдельным клубам
# (используя group_id) и количеству членов
#
# Логика анализа: есть клубы, в которых состоит большее кол-во участников => охват
# потенциальной аудитории более высокий => разумнее сосредоточить таргетированную рекламу соответствующих
# категорий товаров именно в этом сегменте клубов

# %%
# сгруппируем данные по group_id клубов и аггрегируем по числу членов в каждом
df_xyz = members_13.groupby('group_id', as_index = False).agg({'member_name': 'count'}).sort_values('member_name', ascending = False)
df_xyz
# Out:
#       group_id  member_name
# 2896  14213992           31
# 3247  17901622           31
# 6446  23754254           31
# 6578  24189636           30
# 2442   9496682           30
# ...        ...          ...
# 7517  25870263            5
# 2394   8798982            5
# 5091  20339652            5
# 3228  17759102            5
# 336     402853            4
#
# [8035 rows x 2 columns]

# %%
df_xyz.describe([0.33, 0.66, 0.99])[["member_name"]].T
# Out:
#               count       mean       std  min   33%   50%   66%   99%   max
# member_name  8035.0  16.302302  3.994437  4.0  14.0  16.0  18.0  26.0  31.0

# %%
# присвоим значения  по границам Z=33%, Y=66%
df_xyz['xyz'] = np.where(df_xyz['member_name']<14, 'Z', np.where((df_xyz['member_name']<18), 'Y', 'X'))
df_xyz
# Out:
#       group_id  member_name xyz
# 2896  14213992           31   X
# 3247  17901622           31   X
# 6446  23754254           31   X
# 6578  24189636           30   X
# 2442   9496682           30   X
# ...        ...          ...  ..
# 7517  25870263            5   Z
# 2394   8798982            5   Z
# 5091  20339652            5   Z
# 3228  17759102            5   Z
# 336     402853            4   Z
#
# [8035 rows x 3 columns]

# %%
df_xyz.query('xyz == "X"')
# Out:
#       group_id  member_name xyz
# 2896  14213992           31   X
# 3247  17901622           31   X
# 6446  23754254           31   X
# 6578  24189636           30   X
# 2442   9496682           30   X
# ...        ...          ...  ..
# 1195   1673270           18   X
# 467     594908           18   X
# 2291   7859162           18   X
# 459     565564           18   X
# 2141   6290362           18   X
#
# [2946 rows x 3 columns]

# %%
round((2946/8035*100),2)
# Out:
# 36.66

# %%
# объединим таблицы ABC и XYZ групп клубов
df_total = df_abc.merge(df_xyz, on ='group_id')
df_total
# Out:
#       group_id  sum_fee_paid  share_of_total_fees     cum_sum abc  \
# 0     23754254       38095.0             0.044175    0.044175   A
# 1     19012818       36795.0             0.042668    0.086843   A
# 2     10825092       36293.0             0.042086    0.128928   A
# 3      1288361       36127.0             0.041893    0.170821   A
# 4     18383769       34866.0             0.040431    0.211252   A
# ...        ...           ...                  ...         ...  ..
# 7701  24446955         467.0             0.000542   99.998105   C
# 7702   8552732         445.0             0.000516   99.998621   C
# 7703  26157417         430.0             0.000499   99.999120   C
# 7704  24163847         418.0             0.000485   99.999605   C
# 7705  20676096         341.0             0.000395  100.000000   C
#
#       member_name xyz
# 0              31   X
# 1              28   X
# 2              29   X
# 3              28   X
# 4              28   X
# ...           ...  ..
# 7701            9   Z
# 7702            8   Z
# 7703            8   Z
# 7704            8   Z
# 7705            7   Z
#
# [7706 rows x 7 columns]

# %%
pd.crosstab(df_total.abc, df_total.xyz)
# Out:
# xyz     X     Y    Z
# abc
# A    1876  1633  704
# B     495   676  639
# C     454   637  592

# %%
print('зеленая группа', round((((1876+495+454+1633)/7706)*100), 2),'%')
# Out:
# зеленая группа 57.85 %

# %%
df_total_AX = df_total.loc[(df_total.abc=='A') & (df_total.xyz=='X')]
df_total_AX
# Out:
#       group_id  sum_fee_paid  share_of_total_fees    cum_sum abc  member_name  \
# 0     23754254       38095.0             0.044175   0.044175   A           31
# 1     19012818       36795.0             0.042668   0.086843   A           28
# 2     10825092       36293.0             0.042086   0.128928   A           29
# 3      1288361       36127.0             0.041893   0.170821   A           28
# 4     18383769       34866.0             0.040431   0.211252   A           28
# ...        ...           ...                  ...        ...  ..          ...
# 4193   4021122        9683.0             0.011228  79.777349   A           19
# 4197  24195835        9666.0             0.011209  79.822215   A           18
# 4199  20390990        9645.0             0.011184  79.844584   A           22
# 4204  21188207        9625.0             0.011161  79.900432   A           19
# 4209  14783972        9615.0             0.011150  79.956205   A           21
#
#      xyz
# 0      X
# 1      X
# 2      X
# 3      X
# 4      X
# ...   ..
# 4193   X
# 4197   X
# 4199   X
# 4204   X
# 4209   X
#
# [1876 rows x 7 columns]

# %%
# извлечем соответствующие название клубов класса АX из таблицы member_13 и проверим по кол-ву уникальных значений
fun_club_class_AX=df_total_AX.merge(members_13[['group_id', 'fun_club_name']], how='left', on='group_id')
len(list(fun_club_class_AX.fun_club_name.unique()))
# Out:
# 1876

# %%
# распечатем список клубов класса АX. В дальнейшем его можно изпользовать для таргетированной рекламы.
array = fun_club_class_AX.fun_club_name.unique()
class_AX_clubs = pd.DataFrame(array, columns = ['club_name'])
class_AX_clubs
# Out:
#                                     club_name
# 0                   Cultural Explorations NYC
# 1                                Films@Facets
# 2                         New York Kayak Polo
# 3         The New York City MBTI Meetup Group
# 4              Intro to Voice Training -- NYC
# ...                                       ...
# 1871               New York Mets Meetup Group
# 1872  San Francisco Free Art and Music Events
# 1873                The Soca Dance Experience
# 1874  Love My Body Again San Francisco Meetup
# 1875             Composing Film/Game Music SF
#
# [1876 rows x 1 columns]

# %% [raw]
# class_AX_clubs - наиболее "продвинутая" группа клубов с максимально мотивированными и платежеспособными членами
